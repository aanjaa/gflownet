# %%
import pandas
# import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base_path = "/network/scratch/m/moksh.jain/eval-gfn"

# %%
names = ["Random Action", "Random Trajectories", "Tempered Policy", "Temperature Conditioning", "Tempering + Random Action", "No Exploration"]
paths = ["logs/15650steps_20samples_exploration/seh_frag_e_random_action/dataframe.csv", "logs/15650steps_20samples_exploration/seh_frag_e_random_traj/dataframe.csv", "logs/15650steps_20samples_exploration/seh_frag_temp_fixed/dataframe.csv", "logs/15650steps_20samples_exploration/seh_frag_temp_cond/dataframe.csv", "logs/15650steps_20samples_exploration/seh_frag_temp_and_random_action/dataframe.csv", "logs/15650steps_20samples_exploration/seh_frag_no_exploration/dataframe.csv"]
paths = [f"{base_path}/{path}" for path in paths]

# %%
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1, 2, 3, 4, 5])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")

fig.suptitle("sEH - Beta 32")
plt.savefig("seh_beta32_violin.pdf")
# plt.show()

# %%
names = ["Random Action", "Random Trajectories", "Tempered Policy", "Temperature Conditioning", "Tempering + Random Action", "No Exploration"]
paths = ["logs/qed_15650steps_20samples_exploration/qed_frag_e_random_action/dataframe.csv", "logs/qed_15650steps_20samples_exploration/qed_frag_e_random_traj/dataframe.csv", "logs/qed_15650steps_20samples_exploration/qed_frag_temp_fixed/dataframe.csv", "logs/qed_15650steps_20samples_exploration/qed_frag_temp_cond/dataframe.csv", "logs/qed_15650steps_20samples_exploration/qed_frag_temp_and_random_action/dataframe.csv", "logs/qed_15650steps_20samples_exploration/qed_frag_no_exploration/dataframe.csv"]

# %%
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1, 2, 3, 4, 5])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")
# plt.show()

# %%
names = ["Random Action", "Random Trajectories", "Tempered Policy", "Temperature Conditioning", "Tempering + Random Action", "No Exploration"]
paths = ["logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_e_random_action/dataframe.csv", "logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_e_random_traj/dataframe.csv", "logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_temp_fixed/dataframe.csv", "logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_temp_cond/dataframe.csv", "logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_temp_and_random_action/dataframe.csv", "logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_no_exploration/dataframe.csv"]
paths = [f"{base_path}/{path}" for path in paths]

# %%
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1, 2, 3, 4, 5])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")
fig.suptitle("QED - Beta 48")
plt.savefig("qed_beta48_violin.pdf")
# plt.show()

# %%
names = ["Before Fix", "Post Fix"]
paths = ["logs/fixtemp48_qed_15650steps_20samples_exploration/qed_frag_no_exploration/dataframe.csv", "logs/test_rerun_48_qed_15650steps_20samples_exploration/qed_frag_no_exploration/dataframe.csv"]

# %%
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")
# plt.show()

# %%
names = ["Random Action", "Random Trajectories", "Tempered Policy", "Temperature Conditioning", "Tempering + Random Action", "No Exploration"]
paths = ["logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_e_random_action/dataframe.csv", "logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_e_random_traj/dataframe.csv", "logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_temp_fixed/dataframe.csv", "logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_temp_cond/dataframe.csv", "logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_temp_and_random_action/dataframe.csv", "logs/fix_48_drd2_15650steps_20samples_exploration/drd2_frag_no_exploration/dataframe.csv"]
paths = [f"{base_path}/{path}" for path in paths]

# %%
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1, 2, 3, 4, 5])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")
fig.suptitle("DRD2 - Beta 48")
plt.savefig("drd2_beta48_violin.pdf")
# plt.show()

# %%
names = ["Random Action", "Random Trajectories", "Tempered Policy", "Temperature Conditioning", "Tempering + Random Action", "No Exploration"]
paths = ["logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_e_random_action/dataframe.csv", "logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_e_random_traj/dataframe.csv", "logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_temp_fixed/dataframe.csv", "logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_temp_cond/dataframe.csv", "logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_temp_and_random_action/dataframe.csv", "logs/fix_16_drd2_15650steps_20samples_exploration/drd2_frag_no_exploration/dataframe.csv"]
paths = [f"{base_path}/{path}" for path in paths]
cols_to_plot = ["num_of_modes", "avg_topk", "overall_max_reward", "num_candidates_above_reward_thresh"]
col_to_plot = "val_avg_topk"
datas = [[] for _ in cols_to_plot]
data = []
for i, path in enumerate(paths):
    df = pandas.read_csv(path)
    data.append(df[col_to_plot].to_numpy())
    for j, col in enumerate(cols_to_plot):
        datas[j].append(df[col].to_numpy())
    # plt.plot(df[col_to_plot], label=path)
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 10))

for i, ax in enumerate(axs.flat):
    ax.set_title(cols_to_plot[i])
    sns.violinplot(data=datas[i], ax=ax)
    # ax.violinplot(datas[i], showmeans=True)
    if i > 1:
        ax.set_xticks([0, 1, 2, 3, 4, 5])
        ax.set_xticklabels(names)
    # ax.set_xlabel("Exploration Strategy")
    # ax.set_ylabel(cols_to_plot[i])
    plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# axs.violinplot(data, showmeans=True)
fig.suptitle("DRD2 - Beta 16")
plt.savefig("drd2_beta16_violin.pdf")
# # axs.set_xticks([1, 2, 3, 4, 5])
# # axs.set_xticklabels(names)
# axs.set_xlabel("Exploration Strategy")
# axs.set_ylabel("Average Top-k Reward")
# plt.show()
